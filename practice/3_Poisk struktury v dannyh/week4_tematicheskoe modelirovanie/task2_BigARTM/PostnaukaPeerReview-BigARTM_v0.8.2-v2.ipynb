# %% [markdown]
# # Тематическая модель [Постнауки](http://postnauka.ru)
# ## Peer Review (optional)

# %% [markdown]
# В этом задании мы применим аппарат тематического моделирования к коллекции текстовых записей видеолекций, скачанных с сайта Постнаука. Мы будем визуализировать модель и создавать прототип тематического навигатора по коллекции. В коллекции 1728 документов, размер словаря - 38467 слов. Слова лемматизированы, то есть приведены к начальной форме, с помощью программы [mystem](https://tech.yandex.ru/mystem/), коллекция сохранена в [формате vowpal wabbit](http://docs.bigartm.org/en/latest/formats.html). В каждой строке до первой черты записана информация о документе (ссылка на страницу с лекцией), после первой черты следует описание документа. Используются две модальности - текстовая ("text") и модальность авторов ("author"); у каждого документа один автор.

# %% [markdown]
# Для выполнения задания понадобится библиотека [BigARTM](http://docs.bigartm.org). В демонстрации показан пример использования библиотеки версии 0.7.4, на сайте предлагается скачивать версию 0.8.0. В новой версии изменены принципы работы со словарями: они вынесены в отдельный класс (пример в [Release Notes](http://docs.bigartm.org/en/stable/release_notes/python.html)). Строить модель и извлекать ее параметры нужно так же, как показано в демонстрации. Вы можете использовать [предыдущий релиз](http://bigartm.readthedocs.io/en/v0.7.6/download.html) или [новый релиз](http://docs.bigartm.org/en/latest/download.html) на ваше усмотрение.
#
# Спецификации всех функций вы можете смотреть на странице [Python API](http://bigartm.readthedocs.io/en/stable/api_references/python_interface/artm_model.html).

# %%
import artm

# %%
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline
seaborn.set_style("whitegrid", {'axes.grid' : False})

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### Считывание данных

# %% [markdown]
# Создайте объект класса artm.BatchVectorizer, который будет ссылаться на директорию с пакетами данных (батчами). Чтобы библиотека могла преобразовать текстовый файл в батчи, создайте пустую директорию и укажите ее название в параметре target_folder. Размер батча для небольших коллекций (как наша) не важен, вы можете указать любой.

# %%
# Ваш код
batch_vectorizer = artm.BatchVectorizer(data_path="lectures.txt", 
                                        data_format="vowpal_wabbit", 
                                        target_folder="lectures_batches_v2", 
                                        batch_size=100)

# %% [raw]
# # для повторного считывания
# batch_vectorizer = artm.BatchVectorizer(data_path='lectures_batches_v2', data_format='batches')

# %% [markdown]
# ##### Инициализация модели

# %% [markdown]
# Создайте объект класса artm.Model с 30 темами, именами тем, указанными ниже и единичными весами обеих модальностей. Количество тем выбрано не очень большим, чтобы вам было удобнее работать с темами. На этой коллекции можно строить и большее число тем, тогда они будут более узко специализированы.

# %%
T = 30   # количество тем
topic_names=["sbj"+str(i) for i in range(T-1)]+["bcg"]
# Ваш код
model_artm = artm.ARTM(num_topics=T, 
                       topic_names=topic_names, 
                       class_ids={"text":1, "author":1},
                       num_document_passes=1, 
                       reuse_theta=True, 
                       cache_theta=True, 
                       seed=1)
# число после названия модальностей - это их веса

# %% [markdown]
# Мы будем строить 29 предметных тем и одну фоновую.
#
# Соберите словарь с помощью метода gather_dictionary и инициализируйте модель, указав random_seed=1. Обязательно укажите свое название словаря, оно понадобится при добавлении регуляризаторов.

# %%
# Ваш код
#np.random.seed(1)  #похоже, это не очень нужно, уже учтено в предыдущем
dictionary = artm.Dictionary('dictionary')
dictionary.gather(batch_vectorizer.data_path)
model_artm.initialize('dictionary')

# %% [markdown]
# ##### Добавление score

# %% [markdown]
# Создайте два измерителя качества artm.TopTokensScore - по одному для каждой модальности; количество токенов 15. Названия для score придумайте самостоятельно.

# %%
# Ваш код
model_artm.scores.add(artm.TopTokensScore(name="top_words_text", num_tokens=15, class_id="text"))
model_artm.scores.add(artm.TopTokensScore(name="top_words_author", num_tokens=15, class_id="author"))

# %% [markdown]
# ##### Построение модели

# %% [markdown]
# Мы будем строить модель в два этапа: сначала добавим сглаживающий регуляризатор фоновой темы и настроим параметры модели, затем - добавим разреживающий регуляризатор предметрых тем и выполним еще несколько итераций. Так мы сможем получить наиболее чистые от фоновых слов предметные темы. Сглаживающий и разреживающий регуляризаторы задаются одним и тем же классом artm.SmoothSparsePhiRegularizer: если коэффициент tau положительный, то регуляризатор будет сглаживающий, если отрицательный - разреживающий.
#
# Если вы хотите подробнее разобраться, как выполняется регуляризация тематической модели в BigARTM, вы можете прочитать [статью](https://s3-eu-west-1.amazonaws.com/artm/voron-potap14artm-rus.pdf), раздел 4.

# %% [markdown]
# Добавьте сглаживающий регуляризатор с коэффициентом tau = 1e5, указав название своего словаря в dictionary, модальность текста в class_ids и тему "bcg" в topic_names.

# %%
# Ваш код
model_artm.regularizers.add(
    artm.SmoothSparsePhiRegularizer(
        name='SmoothPhi', 
        tau=1e5, 
        dictionary=dictionary, 
        class_ids=["text"], 
        topic_names="bcg"), 
    overwrite=True)

# %% [markdown]
# Выполните 30 итераций по коллекции (num_collection_passes), количество внутренних итераций установите равным 1. Используйте метод fit_offline модели.

# %%
# %%time
# Ваш код
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=30)
# Out:
# Wall time: 24.3 s

# %% [markdown]
# Добавьте разреживающий регуляризатор с коэффициентом tau=-1e5, указав название своего словаря, модальность текста в class_ids и все темы "sbjX" в topic_names.

# %%
# Ваш код
model_artm.regularizers.add(
    artm.SmoothSparsePhiRegularizer(
        name='SparsePhi', 
        tau=-1e5, 
        dictionary=dictionary, 
        class_ids=["text"], 
        topic_names=topic_names[:-1]), 
    overwrite=True)

# %% [markdown]
# Выполните еще 15 проходов по коллекции.

# %%
# %%time
# Ваш код
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)
# Out:
# Wall time: 12.6 s

# %% [markdown]
# ##### Интерпретация тем

# %% [markdown]
# Используя созданные score, выведите топы слов и топы авторов в темах. Удобнее всего выводить топ слов каждой темы с новой строки, указывая название темы в начале строки, и аналогично с авторами.

# %%
# Ваш код
for topic_name in model_artm.topic_names:
    print topic_name + ': ',
    tokens_text = model_artm.score_tracker["top_words_text"].last_tokens
    tokens_author = model_artm.score_tracker["top_words_author"].last_tokens
    print " ".join(tokens_text[topic_name])
    print " ".join(tokens_author[topic_name])
    print
# Out:
# sbj0:  частица взаимодействие физика кварк стандартный симметрия дмитрий элементарный нейтрино материя протон масса слабый фундаментальный построить
# Дмитрий_Казаков Михаил_Данилов Валерий_Рубаков Сергей_Майоров Виктор_Брагута Павел_Пахлов Игорь_Волобуев Лев_Дудко Лев_Беклемишев Анатолий_Лиходед Эдуард_Боос Сергей_Троицкий Дэвид_Гросс Сергей_Гашков Жан-Арыс_Джилкибаев
#
# sbj1:  материал структура температура свойство вещество химический соединение поверхность давление химия применение электронный углерод металл сверхпроводимость
# Артем_Оганов Валерий_Фокин Дмитрий_Паращук Валентин_Ненайденко Владимир_Пудалов Евгений_Гудилин Дмитрий_Гольберг Валентин_Крапошин Иван_Сорокин Наталья_Берлофф Дмитрий_Клинов Сергей_Морозов Евгений_Антипов Вадим_Бражкин Владимир_Комлев
#
# sbj2:  политический государство политика власть царь партия положение труд правитель кризис враг ритуал средневековый сага борьба
# Кирилл_Мартынов Алексей_Юдин Александр_Филиппов Михаил_Бойцов Дина_Гусейнова Иван_Ладынин Андрей_Лукашов Татьяна_Смоктунович Рафаэль_Арутюнян Руслан_Хестанов Ольга_Тогоева Владимир_Малахов Фёдор_Успенский Дмитрий_Баюк Юрий_Рогулёв
#
# sbj3:  университет объяснять школа объект предмет образование естественный познание логика восприятие студент факультет воспринимать учитель аргумент
# Виктор_Вахштайн Наталья_Ростиславлева Григорий_Крейдлин Сергей_Зенкин Татьяна_Клячко Максим_Демин Анатолий_Баранов Мария_Фаликман Дмитрий_Балалыкин Илья_Иткин Ян_Левченко Татьяна_Котова Алексей_Котов Кристофер_Уиншип Александр_Пиперски
#
# sbj4:  слово мозг ребенок категория мышление лицо нейрон предложение конструкция значение корпус позиция контекст взрослый чтение
# Филипп_Хайтович Владимир_Спиридонов Ольга_Сварник Надежда_Онипенко Александр_Каплан Мария_Майофис Катерина_Поливанова Вера_Подлесская Александр_Лазуткин Наталья_Спасская Екатерина_Лютикова Екатерина_Протасова Ноам_Хомский Мария_Фаликман Жанна_Резникова
#
# sbj5:  бог миф греческий герой существо след древний мифология роман грек странный сущность предок персонаж мифологический
# Гасан_Гусейнов Кирилл_Еськов Владимир_Емельянов Андрей_Иванцов Аскольд_Иванчик Андрей_Журавлев Николай_Дронин Григорий_Бондаренко Олег_Ауров Ольга_Тогоева Светлана_Евграфова Александр_Воеводский Ян_Левченко Мария_Неклюдова Алексей_Козырев
#
# sbj6:  русский текст город написать городской перевод сохраняться москва локальный гласный документ немецкий говор письмо пьеса
# Игорь_Исаев Борис_Морозов Леонид_Иомдин Алексей_Бартошевич Ольга_Брилева Дмитрий_Добровольский Александр_Пиперски Оксана_Запорожец Владимир_Кантор Илья_Виньковецкий Михаил_Алексеевский Павел_Руднев Анастасия_Лопухина Алина_Бодрова Павел_Нерлер_(Полян)
#
# sbj7:  трудность раса праздник испытывать участник глаз жертва америка сакральный шаман тест задание станислав нос волос
# Станислав_Дробышевский Александр_Поддьяков Екатерина_Ларионова Елена_Браун Дмитрий_Жуков Валентина_Харитонова Мария_Медникова Григорий_Юдин Марк_Харрисон Наталья_Харламенкова Михаил_Соколов Дмитрий_Беляев Варвара_Веденина Гасан_Гусейнов Андрей_Летаров
#
# sbj8:  право римский правовой закон юрист суд спор юридический душа должник собственность обязательство чужой владение исполнение
# Дмитрий_Дождев Александр_Марей Татьяна_Бобровникова Денис_Новак Дмитрий_Полдников Алексей_Шмелев Фёдор_Успенский Павел_Нерлер_(Полян) Андрей_Чабовский Сет_Ллойд Мира_Бергельсон Андрей_Глазовский ПостНаука Ольга_Вайнштейн Сергей_Неклюдов
#
# sbj9:  медицина врач боль медицинский иммунный вода озеро глубина диагностика фактор климат активация стресс здоровье сознание
# Егор_Задереев Сергей_Румянцев Руслан_Смелянский Константин_Анохин Александр_Аузан Марина_Корсакова-Крейн Антон_Чугунов Денис_Сивков Зоя_Зорина Марина_Бутовская Александр_Петренко Павел_Умрюхин Станислав_Клименко Сергей_Саложин Ирина_Каспэ
#
# sbj10:  животное эволюция робот микроорганизм нервный рецептор эволюционный биологический отбор кислород разнообразие структурный мембрана популяция метан
# Елизавета_Бонч-Осмоловская Алла_Ножевникова Александр_Марков Андрей_Цатурян Дмитрий_Громов Светлана_Дедыш Николай_Пименов Алексей_Кондрашов Сергей_Наугольных Зоригто_Намсараев Евгений_Магид Армен_Мулкиджанян Виктор_Цетлин Дмитрий_Сорокин Алексей_Северцов
#
# sbj11:  память информация когнитивный красный психолог цвет различать зрительный картинка мария внешний окружение запоминать храниться линзовидный
# Мария_Фаликман Кирилл_Титаев Павел_Балабан Константин_Анохин Игорь_Уточкин Сергей_Соколовский Мира_Бергельсон Алексей_Созинов Андрей_Коротаев Алексей_Моисеев Виктор_Мурогов Галина_Зеленина Ави_Лёб Андрей_Кибрик Александр_Мукасьян
#
# sbj12:  историк империя германия государственный западный церковь андрей российский военный великий русь немецкий святой имя князь
# Илья_Женин Фёдор_Успенский Алексей_Миллер Игорь_Данилевский Кирилл_Кочегаров Елена_Уханова Сергей_Серёгичев Александр_Лаврентьев Андрей_Виноградов Владимир_Петрухин Ольга_Эдельман Екатерина_Лямина Алексей_Малашенко Александр_Воеводский Андрей_Кофман
#
# sbj13:  наука социальный история рассказывать понятие общество знание исторический кандидат представление мир современный культурный каков рамка
# Виктор_Вахштайн Виталий_Куренной ПостНаука Елена_Брызгалина Дмитрий_Рогозин Михаил_Маяцкий Павел_Руднев Александр_Гофман Ольга_Артёмова Ольга_Малинова Владимир_Малахов Сергей_Гуриев Наталья_Смолянская Виктор_Полтерович Екатерина_Лапина-Кратасюк
#
# sbj14:  земля галактика планета черный масса дыра вокруг газ атмосфера расстояние солнце диск ядро существование солнечный
# Сергей_Попов Алексей_Расторгуев Ольга_Сильченко Дмитрий_Вибе Владимир_Сурдин Анатолий_Засов Дмитрий_Титов Алексей_Старобинский Наталья_Новикова Александр_Шацкий Сергей_Писарев Александр_Слободкин Роман_Рафиков Сергей_Таскаев Ави_Лёб
#
# sbj15:  решение экономический экономика деньги ваш ресурс выбор компания принятие рабочий международный ценность выбирать рынок сотрудник
# Фуад_Алескеров Алексей_Белянин Владимир_Гимпельсон Сергей_Бобылев Василий_Жарков Ксения_Паниди Антон_Суворов Василий_Ключарев Андрей_Чабовский Константин_Воронцов Джу_Йонг_Ли Анна_Севортьян Эрик_Мэскин Александр_Тхостов Татьяна_Клячко
#
# sbj16:  поведение психология женщина ход психологический конфликт игра совершать эмоция вести объяснение мужчина полагать коллективный родитель
# Михаил_Соколов Мария_Падун Ольга_Гулевич Татьяна_Ребеко Наталья_Харламенкова Александр_Войскунский Махзарин_Банаджи Ольга_Исупова Павел_Нерлер_(Полян) Татьяна_Котова Александр_Филиппов Андрей_Зорин Александр_Каменский Арсений_Хитров Дмитрий_Куракин
#
# sbj17:  задача сеть компьютер набор программа интернет компьютерный обучение ошибка искусственный алгоритм интеллект машина распределение пользователь
# Михаил_Бурцев Александр_Беленький Илья_Шкредов Дмитрий_Ветров Александр_Сафонов Мануэль_Маццара Григорий_Кабатянский Даниэль_Сельва Макс_Тегмарк Сезар_Идальго Михаил_Киселев Петр_Дружинин Дэвид_Кларк Арчил_Балахванцев Николай_Мощевитин
#
# sbj18:  территория восток единый народ древний письменность северный китай памятник южный население восточный море период китайский
# Дмитрий_Беляев Кирилл_Бабаев Георгий_Старостин Марк_Ульянов Алексей_Маслов Анна_Дыбо Дмитрий_Худяков Алексей_Лебедев Сергей_Арутюнов Леонид_Григорьев Борис_Иомдин Евгений_Рогожин Галина_Зеленина Галина_Ершова Александр_Мещеряков
#
# sbj19:  клетка организм ген днк белок молекула генетический биологический последовательность молекулярный геном биология бактерия рнк мутация
# Евгений_Шеваль Константин_Северинов Михаил_Гельфанд Антон_Буздин Андрей_Летаров Александр_Апт Иван_Воробьев Евгений_Куликов Роман_Ефремов Георгий_Базыкин Ричард_Янг Рудольф_Йениш Питер_Лэнсдорп Андрей_Головин Константин_Лукьянов
#
# sbj20:  поле квантовый энергия свет магнитный волна атом электрон измерение эффект фотон эксперимент физико-математический частота оптический
# Владимир_Белотелов Алексей_Рубцов Алексей_Акимов Михаил_Киселев Андрей_Савельев-Трофимов Владимир_Мележик Юджин_Ползик Сергей_Демокритов Пётр_Турчин Владимир_Шалаев Алексей_Желтиков Александр_Львовский Владимир_Кузнецов Михаил_Фейгельман Иван_Луковников
#
# sbj21:  культура философия традиция литература философский писать философ произведение массовый мысль религиозный идеология мать критика автор
# Алексей_Козырев Сергей_Неклюдов Иван_Болдырев Александр_Доброхотов Михаил_Алексеевский Александра_Архипова Петр_Резвых Кирилл_Разлогов Алексей_Руткевич Владимир_Миронов Дина_Гусейнова Александр_Павлов Мария_Неклюдова Ольга_Вайнштейн Дмитрий_Иванов
#
# sbj22:  революция власть король французский против реформа петр франция выступать народ император сталин смерть крестьянин диктатура
# Александр_Марей Олег_Хлевнюк Дмитрий_Бовыкин Павел_Уваров Андрей_Зорин Кирилл_Соловьев Олег_Мельник Игорь_Курукин Алина_Бодрова Илья_Кукулин Михаил_Алексеевский Ольга_Вайнштейн Дмитрий_Дагаев Мохамад_Кассаб Илья_Иткин
#
# sbj23:  россия война советский мировой союз гражданский песня армия екатерина любопытный обряд птица самка ссср самец
# Вера_Мильчина Ирина_Бёме Анна_Соколова Олег_Будницкий Борис_Колоницкий Варвара_Веденина Александр_Каменский Дэвид_Кайзер Людмила_Новикова Михаил_Маяцкий Михаил_Бойцов Алексей_Киличенков Пол_Грегори Архат_Абжанов Марк_Харрисон
#
# sbj24:  язык христианский литературный филологический христианство лингвист глагол лингвистика языковой христианин английский грамматика цивилизация согласный лингвистический
# Алексей_Муравьёв Владимир_Плунгян Олег_Воскобойников Андрей_Кибрик Мария_Штейнман Олег_Лекманов Светлана_Бурлак Петр_Аркадьев Владимир_Беликов Максим_Кронгауз Нина_Сумбатова Варвара_Добровольская Ирина_Левонтина Евгений_Зуев Игорь_Исаев
#
# sbj25:  теория пространство описывать про теоретический описание математический матрица уравнение математика описываться парадокс линейный линия эйнштейн
# Эмиль_Ахмедов Илья_Щуров Алексей_Семихатов Андрей_Лосев Павел_Лушников Владимир_Редько Игорь_Петров Армен_Сергеев Александр_Кислов Елена_Гороховская Владимир_Каганский Александр_Филиппов Сергей_Нечаев Виктор_Авдеев Сергей_Ландо
#
# sbj26:  значение словарь внимание костюм сцена сочетание коллективизация скелет фразеологизм воображение автомобиль долг актер термоэлектрический порнография
# Раиса_Кирсанова Сергей_Пекарский Мария_Фаликман Светлана_Евграфова Александр_Дьяконов Ян_Левченко Андрей_Журавлев Николай_Дронин Денис_Загарин Андрей_Шевельков Наталья_Савва Анатолий_Баранов Александр_Пиперски Игорь_Чубаров Жанна_Резникова
#
# sbj27:  звезда объект вселенная скорость излучение белый измерять нейтронный вещество карлик спектр небо рентгеновский наблюдать короткий
# Сергей_Попов Анатолий_Засов Валерий_Сулейманов Михаил_Ревнивцев Дмитрий_Горбунов Олег_Верходанов Виктория_Битюкова Александр_Потехин Сергей_Блинников Антон_Бирюков Эрик_Мазур Сергей_Троицкий Алексей_Шмелев Уолтер_Льюин Сергей_Шишкин
#
# sbj28:  книга роль фильм свобода посвящать кино автор кинематограф профессор академия культовый академический британский тема журнал
# Александр_Павлов Ивар_Максутов Светлана_Баньковская Павел_Соколов Николай_Плотников Елена_Вишленкова Елизавета_Ривкина Михаил_Эпштейн Александр_Парфенов Екатерина_Щербакова Антон_Бернс Владимир_Каганский Юлия_Краус Ольга_Вайнштейн Герберт_Хупперт
#
# bcg:  быть что это который этот как они мочь такой очень для человек или тот один
# Максим_Франк-Каменецкий Сергей_Киселев Петр_Федичев Александр_Жаворонков Ярослав_Ашихмин Дмитрий_Лось Виталий_Кушниров Алексей_Алексеев Алексей_Чжао Вера_Ижевская Олег_Медведев Александр_Жданов Юрий_Яшков Инга_Полетаева Иван_Оселедец

# %% [markdown]
# В последней теме "bcg" должны находиться общеупотребительные слова.
#
# Важный шаг в работе с тематической моделью, когда речь идет о визуализации или создании тематического навигатора, это именование тем. Понять, о чем каждая тема, можно по списку ее топовых слов. Например, тему
#
#     частица взаимодействие физика кварк симметрия элементарный нейтрино стандартный материя протон бозон заряд масса ускоритель слабый
#
# можно назвать "Физика элементарных частиц".
#
# Дайте названия 29 предметным темам. Если вы не знаете, как назвать тему, назовите ее первым встретившимся в ней существительным, хотя при таком подходе навигатор будет менее информативным. Из названий тем составьте список из 29 строк и запишите его в переменную sbj_topic_labels. В переменной topic_labels будут храниться названия всех тем, включая фоновую.

# %%
sbj_topic_labels = [
   u"физика элементарных частиц",
   u"материаловедение", 
   u"политика", 
   u"университет", 
   u"мозг", 
   u"мифы", 
   u"текстология", 
   u"расы", 
   u"право", 
   u"медицина", 
   u"эволюция", 
   u"память", 
   u"история", 
   u"обществоведение", 
   u"астрофизика", 
   u"экономика", 
   u"психология", 
   u"кибернетика", 
   u"востоковедение", 
   u"генетика", 
   u"квантовая динамика", 
   u"философия", 
   u"французская революция", 
   u"история России", 
   u"лингвистика", 
   u"теория относительности", 
   u"киноискусство", 
   u"астрономия", 
   u"кино"
]
# запишите названия тем в список
topic_labels = sbj_topic_labels + [u"Фоновая тема"]

# %% [markdown]
# ##### Анализ тем

# %% [markdown]
# Далее мы будем работать с распределениями тем в документах (матрица $\Theta$) и авторов в темах (одна из двух матриц $\Phi$, соответствующая модальности авторов).
# Создайте переменные, содержащие две этих матрицы, с помощью методов get_phi и get_theta модели. Назовите переменные theta и phi_a. Выведите формы обеих матриц, чтобы понять, по каким осям стоят темы.

# %%
model_artm.theta_columns_naming = "title" # включает именование столбцов Theta их названиями-ссылками, а не внутренними id 
# Ваш код

theta = model_artm.get_theta()
phi_a = model_artm.get_phi(class_ids=["author"])

print theta.shape, phi_a.shape
# Out:
# (30, 1728) (539, 30)

# %% [markdown]
# Визуализируем фрагмент матрицы $\Theta$ - первые 100 документов (это наиболее простой способ визуально оценить, как темы распределяются в документах). С помощью метода seaborn.heatmap выведите фрагмент theta как изображение. Рекомендация: создайте фигуру pyplot размера (20, 10).

# %%
# Ваш код
plt.figure(figsize=(20, 10))
seaborn.heatmap(theta.iloc[:,:100])
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:

# %% [markdown]
# Вы должны увидеть, что фоновая тема имеет большую вероятность в почти каждом документе, и это логично. Кроме того, есть еще одна тема, которая чаще других встречается в документах. Судя по всему, это тема содержит много слов по науку в целом, а каждый документ (видео) в нашей коллекции связан с наукой. Можно (необязательно) дать этой теме название "Наука".
#
# Помимо этих двух тем, фоновой и общенаучной, каждый документ характеризуется малым числом других тем.

# %% [markdown]
# Оценим $p(t)$ - долю каждой темы во всей коллекции. По формуле полной вероятности вычислять эти величины нужно как
# $p(t) = \sum_d p(t|d) p(d)$. Согласно вероятностной модели, $p(d)$ пропорционально длине документа d. Поступим проще: будем полагать, что все документы равновероятны. Тогда оценить $p(t)$ можно, просуммировав $p(t|d)$ по всем документам, а затем разделив полученный вектор на его сумму.
#
# Создайте переменную-датафрейм с T строками, индексированными названиями тем, и 1 столбцом, содержащим оценки $p(t)$. Выведите датафрейм на печать.

# %%
# Ваш код
pt = pd.DataFrame(theta.sum(axis=1).values / (theta.sum(axis=1).sum()), index=topic_labels, columns=['pt'])

# %% [markdown]
# ПРИМЕЧАНИЕ: в следующих 2-х ячейках маленькое исследование относительно расчета $p(d)$

# %%
theta.shape[1]
# Out:
# 1728

# %%
theta.sum(axis=1).sum()
# Out:
# 1728.0

# %%
pt
# Out:
#                                   pt
# физика элементарных частиц  0.012474
# материаловедение            0.017456
# политика                    0.012020
# университет                 0.009385
# мозг                        0.011483
# мифы                        0.008314
# текстология                 0.009570
# расы                        0.006454
# право                       0.009189
# медицина                    0.008616
# эволюция                    0.015630
# память                      0.006826
# история                     0.018371
# обществоведение             0.058126
# астрофизика                 0.017636
# экономика                   0.010731
# психология                  0.010737
# кибернетика                 0.010180
# востоковедение              0.017473
# генетика                    0.023841
# квантовая динамика          0.018863
# философия                   0.019473
# французская революция       0.010159
# история России              0.007889
# лингвистика                 0.015904
# теория относительности      0.011949
# киноискусство               0.004685
# астрономия                  0.010968
# кино                        0.009079
# Фоновая тема                0.596519

# %% [markdown]
# Найдите 5 самых распространенных и 3 наименее освещенных темы в коллекции (наибольшие и наименьшие $p(t)$ соответственно), не считая фоновую и общенаучную. Укажите названия, которые вы дали этим темам.

# %%
pt.sort_values('pt')
# Out:
#                                   pt
# киноискусство               0.004685
# расы                        0.006454
# память                      0.006826
# история России              0.007889
# мифы                        0.008314
# медицина                    0.008616
# кино                        0.009079
# право                       0.009189
# университет                 0.009385
# текстология                 0.009570
# французская революция       0.010159
# кибернетика                 0.010180
# экономика                   0.010731
# психология                  0.010737
# астрономия                  0.010968
# мозг                        0.011483
# теория относительности      0.011949
# политика                    0.012020
# физика элементарных частиц  0.012474
# эволюция                    0.015630
# лингвистика                 0.015904
# материаловедение            0.017456
# востоковедение              0.017473
# астрофизика                 0.017636
# история                     0.018371
# квантовая динамика          0.018863
# философия                   0.019473
# генетика                    0.023841
# обществоведение             0.058126
# Фоновая тема                0.596519

# %% [raw]
# Ваш ответ:
# 5 тем с max p(t):
# история	0.018371
# квантовая динамика	0.018863
# философия	0.019473
# генетика	0.023841
# обществоведение	0.058126
#
# 3 темы с min p(t):
# киноискусство	0.004685
# расы	0.006454
# память	0.006826

# %% [markdown]
# Визуализируйте матрицу $\Phi$ модальности авторов в виде изображения. Рекомендация: установите yticklabels=False в heatmap.

# %%
# Ваш код
plt.figure(figsize=(20, 10))
seaborn.heatmap(phi_a, yticklabels=False)

# %% [markdown]
# Каждой теме соответствует не очень большое число авторов - матрица достаточно разреженная. Кроме того, некоторые темы имеют доминирующего автора $a$, имеющего большую вероятность $p(a|t)$ - этот автор записал больше всего лекций по теме.

# %% [markdown]
# Будем считать, что автор $a$ значим в теме, если $p(a|t) > 0.01$. Для каждого автора посчитайте, в скольких темах он значим. Найдите авторов-рекордсменов, которые значимы (а значит, читали лекции) в >= 3 темах.

# %%
num_theme = (phi_a > 0.01).sum(axis=1).sort_values(ascending=False)
num_theme[num_theme >= 3]
# Out:
# Мария_Фаликман           4
# Михаил_Алексеевский      4
# Илья_Иткин               4
# Ян_Левченко              4
# Александр_Пиперски       4
# Ольга_Вайнштейн          4
# Андрей_Чабовский         3
# Николай_Дронин           3
# Олег_Ауров               3
# Александр_Филиппов       3
# Александр_Тормасов       3
# Павел_Нерлер_(Полян)     3
# Анатолий_Баранов         3
# Андрей_Журавлев          3
# Константин_Мирошников    3
# Фёдор_Успенский          3
# dtype: int64

# %% [raw]
# Ваш ответ:
# авторы, значимые в не менее чем 3 темах:
# Мария_Фаликман           4
# Михаил_Алексеевский      4
# Илья_Иткин               4
# Ян_Левченко              4
# Александр_Пиперски       4
# Ольга_Вайнштейн          4
# Андрей_Чабовский         3
# Николай_Дронин           3
# Олег_Ауров               3
# Александр_Филиппов       3
# Александр_Тормасов       3
# Павел_Нерлер_(Полян)     3
# Анатолий_Баранов         3
# Андрей_Журавлев          3
# Константин_Мирошников    3
# Фёдор_Успенский          3

# %% [markdown]
# Большинство авторов значимы в 1 теме, что логично.

# %% [markdown]
# ##### Построение тематической карты авторов

# %% [markdown]
# По сути, в матрице $\Phi$, соответствующей модальности авторов, записаны тематические кластеры авторов. Для любого автора мы можем составить его тематический круг - авторов, разбирающихся в той же теме, что и данный. Интересующиеся слушатели могут попробовать выполнить эту процедуру для ученых, читающих лекции на Постнауке, которых они знают (например, на Постнауке есть лекции с К. В. Воронцовым - лектором текущего модуля :)
#
# Составим карту близости авторов по тематике их исследований. Для этого применим метод понижения размерности MDS к тематическим профилям авторов.
#
# Чтобы получить тематический профиль автора, распределение $p(t|a)$, нужно воспользоваться формулой Байеса:
# $p(t|a) = \frac {p(a|t) p(t)} {\sum_t' p(a|t') p(t')}$. Все необходимые для этого величины у вас есть и записаны в переменных phi и pt.
#
# Передайте матрицу тематических профилей авторов, записанных по строкам, в метод MDS с n_components=2. Используйте косинусную метрику (она хорошо подходит для поиска расстояний между векторами, имеющими фиксированную сумму компонент).

# %%
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances

# %%
# Ваш код
p_a = phi_a.values.dot(pt)

p_ta = (phi_a.values.T * pt.values) / p_a.T

# %%
p_ta.shape
# Out:
# (30L, 539L)

# %%
MDS_metod = MDS(dissimilarity="precomputed", random_state=321)
p_taT_pair_cos = pairwise_distances(p_ta[:-1, :].T, metric="cosine")
MDS_transformed_cos = MDS_metod.fit_transform(p_taT_pair_cos)

# %%
#MDS_transformed_cos[:5]

# %% [markdown]
# Визуализируйте найденные двумерные представления с помощью функции scatter.

# %%
# Ваш код
plt.scatter(MDS_transformed_cos[:, 0],
            MDS_transformed_cos[:, 1], c='g', alpha=0.5)

# %% [markdown]
# Должно получиться, что некоторые грппы авторов формируют сгустки, которые можно считать тематическими группами авторов.
#
# Раскрасим точки следующим образом: для каждого автора выберем наиболее вероятную для него тему ($\max_t p(t|a)$), и каждой теме сопоставим цвет. Кроме того, добавим на карту имена и фамилии авторов, это можно сделать в цикле по всем точкам с помощью функции plt.annotate, указывая метку точки первым аргументом и ее координаты в аргументе xy. Рекомендуется сделать размер изображения большим, тогда маркеры точек тоже придется увеличить (s=100 в plt.scatter). Изобразите карту авторов и сохраните в pdf-файл с помощью функции plt.savefig.
#
# Метки авторов будут пересекаться. Будет очень хорошо, если вы найдете способ, как этого можно избежать.

# %%
import matplotlib.cm as cm
colors = cm.rainbow(np.linspace(0, 1, T-1)) # цвета для тем
# Ваш код
max_t_pta = p_ta[:-1, :].argmax(axis=0) # вычисляем номер наиболее вероятной темы для автора
plt.figure(figsize=(20, 10))
for y, c in enumerate(colors):
    plt.scatter(MDS_transformed_cos[max_t_pta==y][:, 0],
            MDS_transformed_cos[max_t_pta==y][:, 1], c=c, s=100, alpha=0.5, label=topic_labels[y])
    plt.legend()

# %%
import matplotlib.cm as cm
colors = cm.rainbow(np.linspace(0, 1, T-1)) # цвета для тем
# Ваш код
max_t_pta = p_ta[:-1, :].argmax(axis=0) # вычисляем номер наиболее вероятной темы для автора

fig = plt.figure(figsize=(20, 30))
for y, c in enumerate(colors):
    plt.scatter(MDS_transformed_cos[max_t_pta==y][:, 0],
            MDS_transformed_cos[max_t_pta==y][:, 1], c=c, s=100, alpha=0.5, label=topic_labels[y])
    plt.legend(loc='lower left')
for i in range(len(phi_a.index)):
    plt.annotate(phi_a.index[i], (MDS_transformed_cos[i, 0], MDS_transformed_cos[i, 1]))
plt.savefig('authors_map.pdf')

# %% [markdown]
# ##### Создание простого тематического навигатора по Постнауке

# %% [markdown]
# Наш тематический навигатор будет для каждой темы показывать ее список слов, а также список релевантных теме документов.
#
# Нам понадобятся распределения $p(d|t)$. По формуле Байеса $p(d|t) = \frac{p(t|d)p(d)}{\sum_{d'}p(t|d')p(d')}$, но поскольку мы считаем документы равновероятными, достаточно разделить каждую строку $\Theta$ на ее сумму, чтобы оценить распределение.
#
# Отсортируйте матрицу $p(d|t)$ по убыванию $p(d|t)$ в каждой теме (то есть построчно). Нам понадобятся индексы наиболее вероятных документов в каждой теме, поэтому используйте функцию argmax.

# %%
p_dt = theta / theta.sum(axis=0)

# %%
p_dt.shape
# Out:
# (30, 1728)

# %%
index = np.argsort(p_dt, axis=1).values

# %% [markdown]
# Создавать навигатор мы будем прямо в jupiter notebook: это возможно благодаря тому факту, что при печати ссылки она автоматически превращается в гиперссылку.

# %%
print "http://yandex.ru"   # получится кликабельная ссылка
# Out:
# http://yandex.ru

# %% [markdown]
# Кроме того, подключив модуль [ipython.core.display](https://ipython.org/ipython-doc/2/api/generated/IPython.core.display.html), можно использовать html-разметку в выводе. Например:

# %%
from IPython.core.display import display, HTML
display(HTML(u'<h1>Заголовок</h1>'))   # также <h2>, <h3>
display(HTML(u"<ul><li>Пункт 1</li><li>Пункт 2</li></ul>"))
display(HTML(u'<font color="green">Зеленый!</font>'))
display(HTML(u'<a href="http://yandex.ru">Еще один вариант вывода ссылки</a>'))
display(HTML(u'<ul><li><a href="http://yandex.ru">http://yandex.ru</a></li></ul>'))
# Out:
# <h1>Заголовок</h1>
# <ul><li>Пункт 1</li><li>Пункт 2</li></ul>
# <font color="green">Зеленый!</font>
# <a href="http://yandex.ru">Еще один вариант вывода ссылки</a>
# <ul><li><a href="http://yandex.ru">http://yandex.ru</a></li></ul>

# %% [markdown]
# В цикле для каждой темы выведите ее заголовок, в следующей строке - топ-10 слов темы, затем в виде списка ссылки на 10 наиболее релевантных (по $p(d|t)$) теме документов. Используйте html-разметку. Творчество приветствуется :)

# %%
# Ваш код

for i, topic_name in enumerate(model_artm.topic_names):
    display(HTML(u"<h1>{}</h1>".format(topic_labels[i])))   # также <h2>, <h3>
    display(HTML(u'<font color="green">{}</font>'.format(" ".join(tokens_text[topic_name]))))
    linklist = ['<li><a href="{}">{}</a></li>'.format(p_dt.columns[index[i, ind]], p_dt.columns[index[i, ind]]) 
                for ind in range(-1, -11, -1)]
    display(HTML(u"<ul>{}</ul>".format("".join(linklist))))
# Out:
# <h1>физика элементарных частиц</h1>
# <font color="green">частица взаимодействие физика кварк стандартный симметрия дмитрий элементарный нейтрино материя протон масса слабый фундаментальный построить</font>
# <ul><li><a href="http://postnauka.ru/video/13043">http://postnauka.ru/video/13043</a></li><li><a href="http://postnauka.ru/video/18870">http://postnauka.ru/video/18870</a></li><li><a href="http://postnauka.ru/video/18873">http://postnauka.ru/video/18873</a></li><li><a href="http://postnauka.ru/video/2945">http://postnauka.ru/video/2945</a></li><li><a href="http://postnauka.ru/video/14282">http://postnauka.ru/video/14282</a></li><li><a href="http://postnauka.ru/video/47952">http://postnauka.ru/video/47952</a></li><li><a href="http://postnauka.ru/video/478">http://postnauka.ru/video/478</a></li><li><a href="http://postnauka.ru/video/47175">http://postnauka.ru/video/47175</a></li><li><a href="http://postnauka.ru/video/47950">http://postnauka.ru/video/47950</a></li><li><a href="http://postnauka.ru/video/1894">http://postnauka.ru/video/1894</a></li></ul>
# <h1>материаловедение</h1>
# <font color="green">материал структура температура свойство вещество химический соединение поверхность давление химия применение электронный углерод металл сверхпроводимость</font>
# <ul><li><a href="http://postnauka.ru/video/31182">http://postnauka.ru/video/31182</a></li><li><a href="http://postnauka.ru/video/13700">http://postnauka.ru/video/13700</a></li><li><a href="http://postnauka.ru/video/57995">http://postnauka.ru/video/57995</a></li><li><a href="http://postnauka.ru/video/41686">http://postnauka.ru/video/41686</a></li><li><a href="http://postnauka.ru/video/18048">http://postnauka.ru/video/18048</a></li><li><a href="http://postnauka.ru/video/23466">http://postnauka.ru/video/23466</a></li><li><a href="http://postnauka.ru/video/50340">http://postnauka.ru/video/50340</a></li><li><a href="http://postnauka.ru/video/13544">http://postnauka.ru/video/13544</a></li><li><a href="http://postnauka.ru/video/46379">http://postnauka.ru/video/46379</a></li><li><a href="http://postnauka.ru/video/51490">http://postnauka.ru/video/51490</a></li></ul>
# <h1>политика</h1>
# <font color="green">политический государство политика власть царь партия положение труд правитель кризис враг ритуал средневековый сага борьба</font>
# <ul><li><a href="http://postnauka.ru/video/13538">http://postnauka.ru/video/13538</a></li><li><a href="http://postnauka.ru/video/52941">http://postnauka.ru/video/52941</a></li><li><a href="http://postnauka.ru/video/5179">http://postnauka.ru/video/5179</a></li><li><a href="http://postnauka.ru/video/9968">http://postnauka.ru/video/9968</a></li><li><a href="http://postnauka.ru/video/12083">http://postnauka.ru/video/12083</a></li><li><a href="http://postnauka.ru/video/32882">http://postnauka.ru/video/32882</a></li><li><a href="http://postnauka.ru/video/32906">http://postnauka.ru/video/32906</a></li><li><a href="http://postnauka.ru/video/7785">http://postnauka.ru/video/7785</a></li><li><a href="http://postnauka.ru/video/21318">http://postnauka.ru/video/21318</a></li><li><a href="http://postnauka.ru/video/5633">http://postnauka.ru/video/5633</a></li></ul>
# <h1>университет</h1>
# <font color="green">университет объяснять школа объект предмет образование естественный познание логика восприятие студент факультет воспринимать учитель аргумент</font>
# <ul><li><a href="http://postnauka.ru/video/2973">http://postnauka.ru/video/2973</a></li><li><a href="http://postnauka.ru/video/31198">http://postnauka.ru/video/31198</a></li><li><a href="http://postnauka.ru/video/35038">http://postnauka.ru/video/35038</a></li><li><a href="http://postnauka.ru/video/55533">http://postnauka.ru/video/55533</a></li><li><a href="http://postnauka.ru/video/19570">http://postnauka.ru/video/19570</a></li><li><a href="http://postnauka.ru/video/40889">http://postnauka.ru/video/40889</a></li><li><a href="http://postnauka.ru/video/49445">http://postnauka.ru/video/49445</a></li><li><a href="http://postnauka.ru/video/50406">http://postnauka.ru/video/50406</a></li><li><a href="http://postnauka.ru/video/55217">http://postnauka.ru/video/55217</a></li><li><a href="http://postnauka.ru/video/3603">http://postnauka.ru/video/3603</a></li></ul>
# <h1>мозг</h1>
# <font color="green">слово мозг ребенок категория мышление лицо нейрон предложение конструкция значение корпус позиция контекст взрослый чтение</font>
# <ul><li><a href="http://postnauka.ru/video/55068">http://postnauka.ru/video/55068</a></li><li><a href="http://postnauka.ru/video/47548">http://postnauka.ru/video/47548</a></li><li><a href="http://postnauka.ru/video/27965">http://postnauka.ru/video/27965</a></li><li><a href="http://postnauka.ru/video/50793">http://postnauka.ru/video/50793</a></li><li><a href="http://postnauka.ru/video/56616">http://postnauka.ru/video/56616</a></li><li><a href="http://postnauka.ru/video/12521">http://postnauka.ru/video/12521</a></li><li><a href="http://postnauka.ru/video/26207">http://postnauka.ru/video/26207</a></li><li><a href="http://postnauka.ru/video/5178">http://postnauka.ru/video/5178</a></li><li><a href="http://postnauka.ru/video/25891">http://postnauka.ru/video/25891</a></li><li><a href="http://postnauka.ru/video/7767">http://postnauka.ru/video/7767</a></li></ul>
# <h1>мифы</h1>
# <font color="green">бог миф греческий герой существо след древний мифология роман грек странный сущность предок персонаж мифологический</font>
# <ul><li><a href="http://postnauka.ru/video/43664">http://postnauka.ru/video/43664</a></li><li><a href="http://postnauka.ru/video/5181">http://postnauka.ru/video/5181</a></li><li><a href="http://postnauka.ru/video/27831">http://postnauka.ru/video/27831</a></li><li><a href="http://postnauka.ru/video/31990">http://postnauka.ru/video/31990</a></li><li><a href="http://postnauka.ru/video/42796">http://postnauka.ru/video/42796</a></li><li><a href="http://postnauka.ru/video/21637">http://postnauka.ru/video/21637</a></li><li><a href="http://postnauka.ru/video/12290">http://postnauka.ru/video/12290</a></li><li><a href="http://postnauka.ru/video/12527">http://postnauka.ru/video/12527</a></li><li><a href="http://postnauka.ru/video/11034">http://postnauka.ru/video/11034</a></li><li><a href="http://postnauka.ru/video/36806">http://postnauka.ru/video/36806</a></li></ul>
# <h1>текстология</h1>
# <font color="green">русский текст город написать городской перевод сохраняться москва локальный гласный документ немецкий говор письмо пьеса</font>
# <ul><li><a href="http://postnauka.ru/video/13156">http://postnauka.ru/video/13156</a></li><li><a href="http://postnauka.ru/video/51171">http://postnauka.ru/video/51171</a></li><li><a href="http://postnauka.ru/video/8964">http://postnauka.ru/video/8964</a></li><li><a href="http://postnauka.ru/video/24279">http://postnauka.ru/video/24279</a></li><li><a href="http://postnauka.ru/video/48112">http://postnauka.ru/video/48112</a></li><li><a href="http://postnauka.ru/video/57318">http://postnauka.ru/video/57318</a></li><li><a href="http://postnauka.ru/video/47301">http://postnauka.ru/video/47301</a></li><li><a href="http://postnauka.ru/video/23470">http://postnauka.ru/video/23470</a></li><li><a href="http://postnauka.ru/video/30657">http://postnauka.ru/video/30657</a></li><li><a href="http://postnauka.ru/video/24945">http://postnauka.ru/video/24945</a></li></ul>
# <h1>расы</h1>
# <font color="green">трудность раса праздник испытывать участник глаз жертва америка сакральный шаман тест задание станислав нос волос</font>
# <ul><li><a href="http://postnauka.ru/video/31707">http://postnauka.ru/video/31707</a></li><li><a href="http://postnauka.ru/video/42707">http://postnauka.ru/video/42707</a></li><li><a href="http://postnauka.ru/video/37732">http://postnauka.ru/video/37732</a></li><li><a href="http://postnauka.ru/video/32898">http://postnauka.ru/video/32898</a></li><li><a href="http://postnauka.ru/video/35150">http://postnauka.ru/video/35150</a></li><li><a href="http://postnauka.ru/video/15341">http://postnauka.ru/video/15341</a></li><li><a href="http://postnauka.ru/video/42735">http://postnauka.ru/video/42735</a></li><li><a href="http://postnauka.ru/video/31675">http://postnauka.ru/video/31675</a></li><li><a href="http://postnauka.ru/video/40880">http://postnauka.ru/video/40880</a></li><li><a href="http://postnauka.ru/video/17397">http://postnauka.ru/video/17397</a></li></ul>
# <h1>право</h1>
# <font color="green">право римский правовой закон юрист суд спор юридический душа должник собственность обязательство чужой владение исполнение</font>
# <ul><li><a href="http://postnauka.ru/video/9299">http://postnauka.ru/video/9299</a></li><li><a href="http://postnauka.ru/video/13042">http://postnauka.ru/video/13042</a></li><li><a href="http://postnauka.ru/video/34414">http://postnauka.ru/video/34414</a></li><li><a href="http://postnauka.ru/video/38009">http://postnauka.ru/video/38009</a></li><li><a href="http://postnauka.ru/video/49455">http://postnauka.ru/video/49455</a></li><li><a href="http://postnauka.ru/video/42221">http://postnauka.ru/video/42221</a></li><li><a href="http://postnauka.ru/video/16822">http://postnauka.ru/video/16822</a></li><li><a href="http://postnauka.ru/video/17912">http://postnauka.ru/video/17912</a></li><li><a href="http://postnauka.ru/video/31666">http://postnauka.ru/video/31666</a></li><li><a href="http://postnauka.ru/video/17875">http://postnauka.ru/video/17875</a></li></ul>
# <h1>медицина</h1>
# <font color="green">медицина врач боль медицинский иммунный вода озеро глубина диагностика фактор климат активация стресс здоровье сознание</font>
# <ul><li><a href="http://postnauka.ru/video/11361">http://postnauka.ru/video/11361</a></li><li><a href="http://postnauka.ru/video/7753">http://postnauka.ru/video/7753</a></li><li><a href="http://postnauka.ru/video/16821">http://postnauka.ru/video/16821</a></li><li><a href="http://postnauka.ru/video/45961">http://postnauka.ru/video/45961</a></li><li><a href="http://postnauka.ru/video/8661">http://postnauka.ru/video/8661</a></li><li><a href="http://postnauka.ru/video/46562">http://postnauka.ru/video/46562</a></li><li><a href="http://postnauka.ru/video/9994">http://postnauka.ru/video/9994</a></li><li><a href="http://postnauka.ru/video/49206">http://postnauka.ru/video/49206</a></li><li><a href="http://postnauka.ru/video/2541">http://postnauka.ru/video/2541</a></li><li><a href="http://postnauka.ru/video/457">http://postnauka.ru/video/457</a></li></ul>
# <h1>эволюция</h1>
# <font color="green">животное эволюция робот микроорганизм нервный рецептор эволюционный биологический отбор кислород разнообразие структурный мембрана популяция метан</font>
# <ul><li><a href="http://postnauka.ru/video/30673">http://postnauka.ru/video/30673</a></li><li><a href="http://postnauka.ru/video/9861">http://postnauka.ru/video/9861</a></li><li><a href="http://postnauka.ru/video/8953">http://postnauka.ru/video/8953</a></li><li><a href="http://postnauka.ru/video/2531">http://postnauka.ru/video/2531</a></li><li><a href="http://postnauka.ru/video/32635">http://postnauka.ru/video/32635</a></li><li><a href="http://postnauka.ru/video/19071">http://postnauka.ru/video/19071</a></li><li><a href="http://postnauka.ru/video/1899">http://postnauka.ru/video/1899</a></li><li><a href="http://postnauka.ru/video/49437">http://postnauka.ru/video/49437</a></li><li><a href="http://postnauka.ru/video/49262">http://postnauka.ru/video/49262</a></li><li><a href="http://postnauka.ru/video/10786">http://postnauka.ru/video/10786</a></li></ul>
# <h1>память</h1>
# <font color="green">память информация когнитивный красный психолог цвет различать зрительный картинка мария внешний окружение запоминать храниться линзовидный</font>
# <ul><li><a href="http://postnauka.ru/video/56052">http://postnauka.ru/video/56052</a></li><li><a href="http://postnauka.ru/video/57336">http://postnauka.ru/video/57336</a></li><li><a href="http://postnauka.ru/video/54916">http://postnauka.ru/video/54916</a></li><li><a href="http://postnauka.ru/video/9997">http://postnauka.ru/video/9997</a></li><li><a href="http://postnauka.ru/video/53949">http://postnauka.ru/video/53949</a></li><li><a href="http://postnauka.ru/video/37979">http://postnauka.ru/video/37979</a></li><li><a href="http://postnauka.ru/video/48109">http://postnauka.ru/video/48109</a></li><li><a href="http://postnauka.ru/video/27845">http://postnauka.ru/video/27845</a></li><li><a href="http://postnauka.ru/video/16159">http://postnauka.ru/video/16159</a></li><li><a href="http://postnauka.ru/video/38507">http://postnauka.ru/video/38507</a></li></ul>
# <h1>история</h1>
# <font color="green">историк империя германия государственный западный церковь андрей российский военный великий русь немецкий святой имя князь</font>
# <ul><li><a href="http://postnauka.ru/video/24034">http://postnauka.ru/video/24034</a></li><li><a href="http://postnauka.ru/video/3406">http://postnauka.ru/video/3406</a></li><li><a href="http://postnauka.ru/video/3348">http://postnauka.ru/video/3348</a></li><li><a href="http://postnauka.ru/video/24039">http://postnauka.ru/video/24039</a></li><li><a href="http://postnauka.ru/video/5464">http://postnauka.ru/video/5464</a></li><li><a href="http://postnauka.ru/video/32637">http://postnauka.ru/video/32637</a></li><li><a href="http://postnauka.ru/video/23900">http://postnauka.ru/video/23900</a></li><li><a href="http://postnauka.ru/video/50668">http://postnauka.ru/video/50668</a></li><li><a href="http://postnauka.ru/video/19574">http://postnauka.ru/video/19574</a></li><li><a href="http://postnauka.ru/video/35041">http://postnauka.ru/video/35041</a></li></ul>
# <h1>обществоведение</h1>
# <font color="green">наука социальный история рассказывать понятие общество знание исторический кандидат представление мир современный культурный каков рамка</font>
# <ul><li><a href="http://postnauka.ru/video/10749">http://postnauka.ru/video/10749</a></li><li><a href="http://postnauka.ru/video/9870">http://postnauka.ru/video/9870</a></li><li><a href="http://postnauka.ru/video/2530">http://postnauka.ru/video/2530</a></li><li><a href="http://postnauka.ru/video/9148">http://postnauka.ru/video/9148</a></li><li><a href="http://postnauka.ru/video/10783">http://postnauka.ru/video/10783</a></li><li><a href="http://postnauka.ru/video/7778">http://postnauka.ru/video/7778</a></li><li><a href="http://postnauka.ru/video/3417">http://postnauka.ru/video/3417</a></li><li><a href="http://postnauka.ru/video/17491">http://postnauka.ru/video/17491</a></li><li><a href="http://postnauka.ru/video/5394">http://postnauka.ru/video/5394</a></li><li><a href="http://postnauka.ru/video/6380">http://postnauka.ru/video/6380</a></li></ul>
# <h1>астрофизика</h1>
# <font color="green">земля галактика планета черный масса дыра вокруг газ атмосфера расстояние солнце диск ядро существование солнечный</font>
# <ul><li><a href="http://postnauka.ru/video/2971">http://postnauka.ru/video/2971</a></li><li><a href="http://postnauka.ru/video/9835">http://postnauka.ru/video/9835</a></li><li><a href="http://postnauka.ru/video/57338">http://postnauka.ru/video/57338</a></li><li><a href="http://postnauka.ru/video/31193">http://postnauka.ru/video/31193</a></li><li><a href="http://postnauka.ru/video/31695">http://postnauka.ru/video/31695</a></li><li><a href="http://postnauka.ru/video/3604">http://postnauka.ru/video/3604</a></li><li><a href="http://postnauka.ru/video/58744">http://postnauka.ru/video/58744</a></li><li><a href="http://postnauka.ru/video/36249">http://postnauka.ru/video/36249</a></li><li><a href="http://postnauka.ru/video/3423">http://postnauka.ru/video/3423</a></li><li><a href="http://postnauka.ru/video/59636">http://postnauka.ru/video/59636</a></li></ul>
# <h1>экономика</h1>
# <font color="green">решение экономический экономика деньги ваш ресурс выбор компания принятие рабочий международный ценность выбирать рынок сотрудник</font>
# <ul><li><a href="http://postnauka.ru/video/53415">http://postnauka.ru/video/53415</a></li><li><a href="http://postnauka.ru/video/5465">http://postnauka.ru/video/5465</a></li><li><a href="http://postnauka.ru/video/24286">http://postnauka.ru/video/24286</a></li><li><a href="http://postnauka.ru/video/13152">http://postnauka.ru/video/13152</a></li><li><a href="http://postnauka.ru/video/27823">http://postnauka.ru/video/27823</a></li><li><a href="http://postnauka.ru/video/51488">http://postnauka.ru/video/51488</a></li><li><a href="http://postnauka.ru/video/28278">http://postnauka.ru/video/28278</a></li><li><a href="http://postnauka.ru/video/14280">http://postnauka.ru/video/14280</a></li><li><a href="http://postnauka.ru/video/7781">http://postnauka.ru/video/7781</a></li><li><a href="http://postnauka.ru/video/43679">http://postnauka.ru/video/43679</a></li></ul>
# <h1>психология</h1>
# <font color="green">поведение психология женщина ход психологический конфликт игра совершать эмоция вести объяснение мужчина полагать коллективный родитель</font>
# <ul><li><a href="http://postnauka.ru/video/22892">http://postnauka.ru/video/22892</a></li><li><a href="http://postnauka.ru/video/21643">http://postnauka.ru/video/21643</a></li><li><a href="http://postnauka.ru/video/22883">http://postnauka.ru/video/22883</a></li><li><a href="http://postnauka.ru/video/40866">http://postnauka.ru/video/40866</a></li><li><a href="http://postnauka.ru/video/26223">http://postnauka.ru/video/26223</a></li><li><a href="http://postnauka.ru/video/21661">http://postnauka.ru/video/21661</a></li><li><a href="http://postnauka.ru/video/9729">http://postnauka.ru/video/9729</a></li><li><a href="http://postnauka.ru/video/9865">http://postnauka.ru/video/9865</a></li><li><a href="http://postnauka.ru/video/37956">http://postnauka.ru/video/37956</a></li><li><a href="http://postnauka.ru/video/2946">http://postnauka.ru/video/2946</a></li></ul>
# <h1>кибернетика</h1>
# <font color="green">задача сеть компьютер набор программа интернет компьютерный обучение ошибка искусственный алгоритм интеллект машина распределение пользователь</font>
# <ul><li><a href="http://postnauka.ru/video/32901">http://postnauka.ru/video/32901</a></li><li><a href="http://postnauka.ru/video/8313">http://postnauka.ru/video/8313</a></li><li><a href="http://postnauka.ru/video/55303">http://postnauka.ru/video/55303</a></li><li><a href="http://postnauka.ru/video/47810">http://postnauka.ru/video/47810</a></li><li><a href="http://postnauka.ru/video/13155">http://postnauka.ru/video/13155</a></li><li><a href="http://postnauka.ru/video/26607">http://postnauka.ru/video/26607</a></li><li><a href="http://postnauka.ru/video/12172">http://postnauka.ru/video/12172</a></li><li><a href="http://postnauka.ru/video/25326">http://postnauka.ru/video/25326</a></li><li><a href="http://postnauka.ru/video/9998">http://postnauka.ru/video/9998</a></li><li><a href="http://postnauka.ru/video/12524">http://postnauka.ru/video/12524</a></li></ul>
# <h1>востоковедение</h1>
# <font color="green">территория восток единый народ древний письменность северный китай памятник южный население восточный море период китайский</font>
# <ul><li><a href="http://postnauka.ru/video/53171">http://postnauka.ru/video/53171</a></li><li><a href="http://postnauka.ru/video/59201">http://postnauka.ru/video/59201</a></li><li><a href="http://postnauka.ru/video/5891">http://postnauka.ru/video/5891</a></li><li><a href="http://postnauka.ru/video/2527">http://postnauka.ru/video/2527</a></li><li><a href="http://postnauka.ru/video/51380">http://postnauka.ru/video/51380</a></li><li><a href="http://postnauka.ru/video/12515">http://postnauka.ru/video/12515</a></li><li><a href="http://postnauka.ru/video/17041">http://postnauka.ru/video/17041</a></li><li><a href="http://postnauka.ru/video/56302">http://postnauka.ru/video/56302</a></li><li><a href="http://postnauka.ru/video/25290">http://postnauka.ru/video/25290</a></li><li><a href="http://postnauka.ru/video/52958">http://postnauka.ru/video/52958</a></li></ul>
# <h1>генетика</h1>
# <font color="green">клетка организм ген днк белок молекула генетический биологический последовательность молекулярный геном биология бактерия рнк мутация</font>
# <ul><li><a href="http://postnauka.ru/video/5390">http://postnauka.ru/video/5390</a></li><li><a href="http://postnauka.ru/video/9727">http://postnauka.ru/video/9727</a></li><li><a href="http://postnauka.ru/video/17051">http://postnauka.ru/video/17051</a></li><li><a href="http://postnauka.ru/video/10475">http://postnauka.ru/video/10475</a></li><li><a href="http://postnauka.ru/video/27434">http://postnauka.ru/video/27434</a></li><li><a href="http://postnauka.ru/video/16156">http://postnauka.ru/video/16156</a></li><li><a href="http://postnauka.ru/video/32881">http://postnauka.ru/video/32881</a></li><li><a href="http://postnauka.ru/video/37537">http://postnauka.ru/video/37537</a></li><li><a href="http://postnauka.ru/video/35051">http://postnauka.ru/video/35051</a></li><li><a href="http://postnauka.ru/video/5915">http://postnauka.ru/video/5915</a></li></ul>
# <h1>квантовая динамика</h1>
# <font color="green">поле квантовый энергия свет магнитный волна атом электрон измерение эффект фотон эксперимент физико-математический частота оптический</font>
# <ul><li><a href="http://postnauka.ru/video/21662">http://postnauka.ru/video/21662</a></li><li><a href="http://postnauka.ru/video/19457">http://postnauka.ru/video/19457</a></li><li><a href="http://postnauka.ru/video/24434">http://postnauka.ru/video/24434</a></li><li><a href="http://postnauka.ru/video/19509">http://postnauka.ru/video/19509</a></li><li><a href="http://postnauka.ru/video/51174">http://postnauka.ru/video/51174</a></li><li><a href="http://postnauka.ru/video/18221">http://postnauka.ru/video/18221</a></li><li><a href="http://postnauka.ru/video/25875">http://postnauka.ru/video/25875</a></li><li><a href="http://postnauka.ru/video/3381">http://postnauka.ru/video/3381</a></li><li><a href="http://postnauka.ru/video/26609">http://postnauka.ru/video/26609</a></li><li><a href="http://postnauka.ru/video/23335">http://postnauka.ru/video/23335</a></li></ul>
# <h1>философия</h1>
# <font color="green">культура философия традиция литература философский писать философ произведение массовый мысль религиозный идеология мать критика автор</font>
# <ul><li><a href="http://postnauka.ru/video/2529">http://postnauka.ru/video/2529</a></li><li><a href="http://postnauka.ru/video/7764">http://postnauka.ru/video/7764</a></li><li><a href="http://postnauka.ru/video/12738">http://postnauka.ru/video/12738</a></li><li><a href="http://postnauka.ru/video/23834">http://postnauka.ru/video/23834</a></li><li><a href="http://postnauka.ru/video/22570">http://postnauka.ru/video/22570</a></li><li><a href="http://postnauka.ru/video/9728">http://postnauka.ru/video/9728</a></li><li><a href="http://postnauka.ru/video/32664">http://postnauka.ru/video/32664</a></li><li><a href="http://postnauka.ru/video/7068">http://postnauka.ru/video/7068</a></li><li><a href="http://postnauka.ru/video/53513">http://postnauka.ru/video/53513</a></li><li><a href="http://postnauka.ru/video/26234">http://postnauka.ru/video/26234</a></li></ul>
# <h1>французская революция</h1>
# <font color="green">революция власть король французский против реформа петр франция выступать народ император сталин смерть крестьянин диктатура</font>
# <ul><li><a href="http://postnauka.ru/video/53577">http://postnauka.ru/video/53577</a></li><li><a href="http://postnauka.ru/video/3599">http://postnauka.ru/video/3599</a></li><li><a href="http://postnauka.ru/video/48492">http://postnauka.ru/video/48492</a></li><li><a href="http://postnauka.ru/video/54175">http://postnauka.ru/video/54175</a></li><li><a href="http://postnauka.ru/video/47823">http://postnauka.ru/video/47823</a></li><li><a href="http://postnauka.ru/video/58542">http://postnauka.ru/video/58542</a></li><li><a href="http://postnauka.ru/video/1893">http://postnauka.ru/video/1893</a></li><li><a href="http://postnauka.ru/video/25882">http://postnauka.ru/video/25882</a></li><li><a href="http://postnauka.ru/video/42993">http://postnauka.ru/video/42993</a></li><li><a href="http://postnauka.ru/video/23161">http://postnauka.ru/video/23161</a></li></ul>
# <h1>история России</h1>
# <font color="green">россия война советский мировой союз гражданский песня армия екатерина любопытный обряд птица самка ссср самец</font>
# <ul><li><a href="http://postnauka.ru/video/34413">http://postnauka.ru/video/34413</a></li><li><a href="http://postnauka.ru/video/30261">http://postnauka.ru/video/30261</a></li><li><a href="http://postnauka.ru/video/46939">http://postnauka.ru/video/46939</a></li><li><a href="http://postnauka.ru/video/25906">http://postnauka.ru/video/25906</a></li><li><a href="http://postnauka.ru/video/52936">http://postnauka.ru/video/52936</a></li><li><a href="http://postnauka.ru/video/57259">http://postnauka.ru/video/57259</a></li><li><a href="http://postnauka.ru/video/25890">http://postnauka.ru/video/25890</a></li><li><a href="http://postnauka.ru/video/41680">http://postnauka.ru/video/41680</a></li><li><a href="http://postnauka.ru/video/47816">http://postnauka.ru/video/47816</a></li><li><a href="http://postnauka.ru/video/55219">http://postnauka.ru/video/55219</a></li></ul>
# <h1>лингвистика</h1>
# <font color="green">язык христианский литературный филологический христианство лингвист глагол лингвистика языковой христианин английский грамматика цивилизация согласный лингвистический</font>
# <ul><li><a href="http://postnauka.ru/video/7755">http://postnauka.ru/video/7755</a></li><li><a href="http://postnauka.ru/video/13041">http://postnauka.ru/video/13041</a></li><li><a href="http://postnauka.ru/video/55301">http://postnauka.ru/video/55301</a></li><li><a href="http://postnauka.ru/video/52778">http://postnauka.ru/video/52778</a></li><li><a href="http://postnauka.ru/video/6720">http://postnauka.ru/video/6720</a></li><li><a href="http://postnauka.ru/video/53169">http://postnauka.ru/video/53169</a></li><li><a href="http://postnauka.ru/video/10473">http://postnauka.ru/video/10473</a></li><li><a href="http://postnauka.ru/video/9556">http://postnauka.ru/video/9556</a></li><li><a href="http://postnauka.ru/video/16157">http://postnauka.ru/video/16157</a></li><li><a href="http://postnauka.ru/video/11653">http://postnauka.ru/video/11653</a></li></ul>
# <h1>теория относительности</h1>
# <font color="green">теория пространство описывать про теоретический описание математический матрица уравнение математика описываться парадокс линейный линия эйнштейн</font>
# <ul><li><a href="http://postnauka.ru/video/3388">http://postnauka.ru/video/3388</a></li><li><a href="http://postnauka.ru/video/36804">http://postnauka.ru/video/36804</a></li><li><a href="http://postnauka.ru/video/57128">http://postnauka.ru/video/57128</a></li><li><a href="http://postnauka.ru/video/34416">http://postnauka.ru/video/34416</a></li><li><a href="http://postnauka.ru/video/55069">http://postnauka.ru/video/55069</a></li><li><a href="http://postnauka.ru/video/18086">http://postnauka.ru/video/18086</a></li><li><a href="http://postnauka.ru/video/18085">http://postnauka.ru/video/18085</a></li><li><a href="http://postnauka.ru/video/51371">http://postnauka.ru/video/51371</a></li><li><a href="http://postnauka.ru/video/19456">http://postnauka.ru/video/19456</a></li><li><a href="http://postnauka.ru/video/25278">http://postnauka.ru/video/25278</a></li></ul>
# <h1>киноискусство</h1>
# <font color="green">значение словарь внимание костюм сцена сочетание коллективизация скелет фразеологизм воображение автомобиль долг актер термоэлектрический порнография</font>
# <ul><li><a href="http://postnauka.ru/video/31684">http://postnauka.ru/video/31684</a></li><li><a href="http://postnauka.ru/video/9389">http://postnauka.ru/video/9389</a></li><li><a href="http://postnauka.ru/video/43843">http://postnauka.ru/video/43843</a></li><li><a href="http://postnauka.ru/video/49866">http://postnauka.ru/video/49866</a></li><li><a href="http://postnauka.ru/video/40004">http://postnauka.ru/video/40004</a></li><li><a href="http://postnauka.ru/video/37978">http://postnauka.ru/video/37978</a></li><li><a href="http://postnauka.ru/video/46559">http://postnauka.ru/video/46559</a></li><li><a href="http://postnauka.ru/video/57127">http://postnauka.ru/video/57127</a></li><li><a href="http://postnauka.ru/video/30601">http://postnauka.ru/video/30601</a></li><li><a href="http://postnauka.ru/video/57524">http://postnauka.ru/video/57524</a></li></ul>
# <h1>астрономия</h1>
# <font color="green">звезда объект вселенная скорость излучение белый измерять нейтронный вещество карлик спектр небо рентгеновский наблюдать короткий</font>
# <ul><li><a href="http://postnauka.ru/video/53693">http://postnauka.ru/video/53693</a></li><li><a href="http://postnauka.ru/video/6673">http://postnauka.ru/video/6673</a></li><li><a href="http://postnauka.ru/video/30015">http://postnauka.ru/video/30015</a></li><li><a href="http://postnauka.ru/video/17779">http://postnauka.ru/video/17779</a></li><li><a href="http://postnauka.ru/video/10756">http://postnauka.ru/video/10756</a></li><li><a href="http://postnauka.ru/video/12125">http://postnauka.ru/video/12125</a></li><li><a href="http://postnauka.ru/video/23969">http://postnauka.ru/video/23969</a></li><li><a href="http://postnauka.ru/video/59202">http://postnauka.ru/video/59202</a></li><li><a href="http://postnauka.ru/video/12372">http://postnauka.ru/video/12372</a></li><li><a href="http://postnauka.ru/video/49447">http://postnauka.ru/video/49447</a></li></ul>
# <h1>кино</h1>
# <font color="green">книга роль фильм свобода посвящать кино автор кинематограф профессор академия культовый академический британский тема журнал</font>
# <ul><li><a href="http://postnauka.ru/video/5396">http://postnauka.ru/video/5396</a></li><li><a href="http://postnauka.ru/video/39723">http://postnauka.ru/video/39723</a></li><li><a href="http://postnauka.ru/video/9429">http://postnauka.ru/video/9429</a></li><li><a href="http://postnauka.ru/video/10779">http://postnauka.ru/video/10779</a></li><li><a href="http://postnauka.ru/video/11246">http://postnauka.ru/video/11246</a></li><li><a href="http://postnauka.ru/video/8623">http://postnauka.ru/video/8623</a></li><li><a href="http://postnauka.ru/video/7074">http://postnauka.ru/video/7074</a></li><li><a href="http://postnauka.ru/video/47208">http://postnauka.ru/video/47208</a></li><li><a href="http://postnauka.ru/video/47202">http://postnauka.ru/video/47202</a></li><li><a href="http://postnauka.ru/video/45548">http://postnauka.ru/video/45548</a></li></ul>
# <h1>Фоновая тема</h1>
# <font color="green">быть что это который этот как они мочь такой очень для человек или тот один</font>
# <ul><li><a href="http://postnauka.ru/video/48116">http://postnauka.ru/video/48116</a></li><li><a href="http://postnauka.ru/video/57657">http://postnauka.ru/video/57657</a></li><li><a href="http://postnauka.ru/video/44543">http://postnauka.ru/video/44543</a></li><li><a href="http://postnauka.ru/video/34422">http://postnauka.ru/video/34422</a></li><li><a href="http://postnauka.ru/video/54479">http://postnauka.ru/video/54479</a></li><li><a href="http://postnauka.ru/video/60527">http://postnauka.ru/video/60527</a></li><li><a href="http://postnauka.ru/video/2970">http://postnauka.ru/video/2970</a></li><li><a href="http://postnauka.ru/video/18613">http://postnauka.ru/video/18613</a></li><li><a href="http://postnauka.ru/video/43853">http://postnauka.ru/video/43853</a></li><li><a href="http://postnauka.ru/video/55150">http://postnauka.ru/video/55150</a></li></ul>

# %% [markdown]
# ##### Заключение

# %% [markdown]
# В этом Peer Review мы познакомились с базовыми возможностями библиотеки BigARTM и с методами визуализации тематических моделей. Визуализация тематических моделей - это широкая и активно развивающаяся область научных исследований. Мы рассмотрели только самые простые приемы. Желающие могут попробовать применить [Serendip](http://vep.cs.wisc.edu/serendip/#serendipHero), разработанный в  University of Wisconsin-Madison, к построенной модели. Эта библиотека позволяет максимально полно охарактеризовать темы и написана для языка python.
#
# Сделав задание, вы можете выбрать в навигаторе наиболее интересную для вас тему и посмотреть видеолекции :) На Постнауке очень много интересных материалов.
